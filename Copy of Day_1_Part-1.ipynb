# %% [markdown]
# ##Use of Semicolon
# It is not compulsory but doesn't throw an error if we use it.
#
# A semicolon in Python denotes separation, rather than termination.

# %%
print('Hello World'); print("IEEE")
# Out:
# Hello World
# IEEE

# %% [markdown]
# ##Indentation
# Python uses spaces before code of line and does not use curly braces {} to seperate a code of block.
#
# Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important. Python uses indentation to indicate a block of code.

# %%
a = 'Hello World'
print(a)

# %%
if 5>3:
  print('Yes')
# Out:
# Yes

# %% [markdown]
# ##Keywords in Python
# Keywords are reserved words and cannot be used as an identifier.

# %%
true = 14000
print(true)
# Out:
# 14000

# %% [markdown]
# ##Variables
# Value is given a memory address not the variable.
#
# A variable is a tag or name for this very memory address.

# %% [markdown]
# ###Declare a Variable

# %%
a = 10
b = 10
print('a = ' , id(a)) #id is used to get the memory address
print('b = ' , id(b))
# Out:
# a =  9793376
# b =  9793376

# %% [markdown]
# ###Re-declare a Variable

# %%
b = 251
print('a = ' , id(a))
print('b = ' , id(b))
# Out:
# a =  9793376
# b =  9801088

# %%
a = 53
print('a = ' , id(a))
print('b = ' , id(b))
# Out:
# a =  9794752
# b =  9801088

# %% [markdown]
# ###Assigning a single value to multiple variables

# %%
a = b = c = 10
print(a)
print(b)
print(c)
# Out:
# 10
# 10
# 10

# %% [markdown]
# ###Assigning different values to multiple variables

# %%
a, b, c = 1, 20.5, "IEEE Workshop" 
print(a) print(b)
print(c)
# Out:
#   File "<ipython-input-1-c739c6ca5ba4>", line 2
#     print(a) print(b)
#              ^
# SyntaxError: invalid syntax

# %%
a, b, c = 1, 20.5, "IEEE Workshop" 
print(a)
print(b)
print(c)
# Out:
# 1
# 20.5
# IEEE Workshop

# %% [markdown]
# ###Guess the output...

# %%
a = 10
a = "IEEE Workshop" 
print(a)
# Out:
# IEEE Workshop

# %% [markdown]
# ###Can we use the same name for different types?
# If we use the same name, the variable starts referring to a new value and type.

# %% [markdown]
# ##Constants
# Variables in capital letters.
#
# Its a convention and does not really prevent reassigning of values.
#
# Usually constants are declared in a module which is then imported to the main file.

# %%
PI = 3.14
GRAVITY = 9.8
print(PI)
# Out:
# 3.14

# %%
a = '1'
b = '2'
print(a+b)
# Out:
# 12

# %% [markdown]
# ##Data Types

# %% [markdown]
# ###Complex Number

# %%
num = 6 + 9j
print(num)
print(type(num))
# Out:
# (6+9j)
# <class 'complex'>

# %% [markdown]
# ##Typecasting or Type Conversion
# Conversion of one data type into another.

# %% [markdown]
# ###Explicit Typecasting
# Done via programmer's intervention or manually as pe requirement.
#
# Example: int(), float(), str(), dict(), set(), list(), etc.

# %%
a = '1'
b = '2'
print(int(a) + int(b))
# Out:
# 3

# %% [markdown]
# ###Implicit Typecasting
# Python converts a smaller datatype to a higher datatype to prevent data loss.

# %%
a = 10
b = 6.9
c = a+b
print(c)
print(type(c))
# Out:
# 16.9
# <class 'float'>

# %% [markdown]
# ##Scope of Variable

# %%
x = 10 #Global

def india():
  x = 50 #Enclosing

  def dholakpur():
    x = 100 #Local
    print('Dholakpur = ' , x)

  dholakpur()
  print('India = ' , x)

india()
print('Global = ' , x)
# Out:
# Dholakpur =  100
# India =  50
# Global =  10

# %% [markdown]
# ##Comments
# Code Readability
#
# Explanation of the code or Metadata of the project
#
# Prevent execution of code
#
# To include resources

# %% [markdown]
# ###Single Line

# %%
#This is a single line comment
print('IEEE Python Workshop')
# Out:
# IEEE Python Workshop

# %% [markdown]
# ###Multiline

# %%
#Welcome to
#python

# %% [markdown]
# ###Docstring

# %%
'''Hello everyone
Welcome to
fbeywui
ComputationalThinking.py'''
print('Hello')
# Out:
# Hello
